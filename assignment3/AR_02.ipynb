# %%
from statsmodels.tsa.arima_process import ArmaProcess
import numpy as np
import pandas as pd

# %%
ar1 = np.array([1, -0.8])
ma1 = np.array([1])
AR_object1 = ArmaProcess(ar1, ma1)
simulated_data = AR_object1.generate_sample(nsample=500)

# %%
import matplotlib.pyplot as plt 
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_acf(simulated_data, lags= 100)

# %%
plot_pacf(simulated_data, lags = 50)

# %%
ar1 = np.array([1, -0.5])
ma1 = np.array([1])
AR_object1 = ArmaProcess(ar1, ma1)
simulated_data = AR_object1.generate_sample(nsample=500)

# %%
plot_acf(simulated_data, lags= 100)

# %%
plot_pacf(simulated_data, lags = 50)

# %%
ar1 = np.array([1, -0.2])
ma1 = np.array([1])
AR_object1 = ArmaProcess(ar1, ma1)
simulated_data = AR_object1.generate_sample(nsample=500)

# %%
plot_acf(simulated_data, lags= 100)

# %%
plot_pacf(simulated_data, lags = 50)

# %% [markdown]
# with decrease in values of phi magnitude in acf and pacf plot decreases

# %%
path='https://raw.githubusercontent.com/gaurav15raj/Time_Series-Econs-/main/AR%20Processes/Sim1.csv'
df=pd.read_csv(path)
df.columns
# Out:
# Index(['Unnamed: 0', '0'], dtype='object')

# %%
df=df.drop("Unnamed: 0",axis=1)

# %%
plot_acf(simulated_data, lags= 100)

# %%
plot_pacf(df,lags=50)

# %% [markdown]
# Yes it is an AR process of order 3

# %%
path='https://raw.githubusercontent.com/gaurav15raj/Time_Series-Econs-/main/AR%20Processes/output.csv'
df=pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0        Date      Prices
# 0           0  2022-01-01   99.346617
# 1           1  2022-01-02   99.563825
# 2           2  2022-01-03  100.163220
# 3           3  2022-01-04   99.841533
# 4           4  2022-01-05  101.927683

# %%
plot_acf(df.Prices)

# %%
plot_pacf(df.Prices,lags=50)

# %% [markdown]
# Yes it is an AR process of order 3

# %%
path='https://raw.githubusercontent.com/gaurav15raj/Time_Series-Econs-/main/AR%20Processes/sales-of-shampoo-over-a-three-ye.csv'
df=pd.read_csv(path)
df.columns
# Out:
# Index(['Month', 'Sales of shampoo over a three year period'], dtype='object')

# %%
df=df.drop("Month",axis=1)

# %%
plot_acf(df, lags=30)

# %%
plot_pacf(df,lags=15)

# %% [markdown]
# No,it is not an AR process

# %%
path='https://raw.githubusercontent.com/gaurav15raj/Time_Series-Econs-/main/AR%20Processes/Electric_Production.csv'
df=pd.read_csv(path)
df.columns
# Out:
# Index(['DATE', 'IPG2211A2N'], dtype='object')

# %%
df=df.drop("DATE",axis=1)

# %%
plot_acf(df,lags=100)

# %%
plot_pacf(df,lags=50)
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/regression/linear_model.py:1434: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# NO, it is not an AR process
